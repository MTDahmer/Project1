# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import os
import sys
import numpy as np

csv1 = '../data/overdose_counts.csv'
csv2 = '../data/opiate_prescribers15.csv'
csv3 = '../data/opiate_prescribers16.csv'
csv4 = '../data/physician_ratings16.csv'
csv5 = '../data/physician_ratings15.csv'
csv6 = '../data/Physician_Compare_2015_Group_Patient_Experience.csv'
csv7 = '../data/Physician_Compare_2016_Group_Patient_Experience.csv'

output1 = '../Presentation/Clean/op_final_15.csv'
output2 = '../Presentation/Clean/op_final_16.csv'

overdose_counts = pd.read_csv(csv1)
op_prescriber15 = pd.read_csv(csv2)
op_prescriber16 = pd.read_csv(csv3)
phys_ratings16 = pd.read_csv(csv4)
phys_ratings15 = pd.read_csv(csv5)
pc_rating15 = pd.read_csv(csv6)
pc_rating16 = pd.read_csv(csv7)

# %%
#raw dataframe
overdose_counts.head()
# Out:
#                                                                                                                                  VSRR_Provisional_Drug_Overdose_Death_Counts
# State State Name Year Month    Indicator        Data Value Predicted Value Percent Complete Percent Pending Investigation                                           Footnote
# AK    AK         2015 January  Number of Deaths 4,034      NaN             100              0                              Numbers may differ from published reports usin...
#                       February Number of Deaths 4,084      NaN             100              0                              Numbers may differ from published reports usin...
#                       March    Number of Deaths 4,101      NaN             100              0                              Numbers may differ from published reports usin...
# ...

# %%
#reset index
odcount = overdose_counts.reset_index()
odcount
# Out:
#       level_0     level_1 level_2    level_3  \
# 0       State  State Name    Year      Month
# 1          AK          AK    2015    January
# 2          AK          AK    2015   February
# 3          AK          AK    2015      March
# 4          NM          NM    2018    January
# 5          AK          AK    2015      April
# 6          AK          AK    2015        May
# 7          NM          NM    2018   February
# 8          NM          NM    2018      March
# 9          NM          NM    2018      April
# 10         AK          AK    2015       June
# 11         NM          NM    2018        May
# 12         NM          NM    2018       June
# 13         AK          AK    2015    January
# 14         AK          AK    2015   February
# 15         AK          AK    2015      March
# 16         AK          AK    2015      April
# 17         AK          AK    2015        May
# 18         AK          AK    2015       June
# 19         AK          AK    2015       July
# ...

# %%
#drop unnecessary columns
odcount = odcount.drop(columns=['level_1','level_6','level_7','level_8','VSRR_Provisional_Drug_Overdose_Death_Counts'])
odcount.head()
# Out:
#   level_0 level_2   level_3           level_4     level_5
# 0   State    Year     Month         Indicator  Data Value
# 1      AK    2015   January  Number of Deaths       4,034
# 2      AK    2015  February  Number of Deaths       4,084
# 3      AK    2015     March  Number of Deaths       4,101
# 4      NM    2018   January  Number of Deaths      18,147

# %%
#rename columns
odcount = odcount.rename(columns={'level_0':'State','level_2':'Year','level_3':'Month','level_4':'Indicator','level_5':'Overdose'})
odcount.head()
# Out:
#    State  Year     Month         Indicator    Overdose
# 0  State  Year     Month         Indicator  Data Value
# 1     AK  2015   January  Number of Deaths       4,034
# 2     AK  2015  February  Number of Deaths       4,084
# 3     AK  2015     March  Number of Deaths       4,101
# 4     NM  2018   January  Number of Deaths      18,147

# %%
#drop index 0 and print data frame
deathcounts = odcount.drop([0])
deathcounts.head()
# Out:
#   State  Year     Month         Indicator Overdose
# 1    AK  2015   January  Number of Deaths    4,034
# 2    AK  2015  February  Number of Deaths    4,084
# 3    AK  2015     March  Number of Deaths    4,101
# 4    NM  2018   January  Number of Deaths   18,147
# 5    AK  2015     April  Number of Deaths    4,133

# %%
#Opiate Prescribers-2015 data frame
op_prescriber15.head()
# Out:
#           NPI NPPES Provider Last Name NPPES Provider First Name  \
# 0  1003000126                ENKESHAFI                   ARDALAN
# 1  1003000142                   KHALIL                    RASHID
# 2  1003000167                  ESCOBAR                     JULIO
# 3  1003000175            REYES-VASQUEZ                   BELINDA
# 4  1003000282                BLAKEMORE                     ROSIE
#
#    NPPES Provider ZIP Code NPPES Provider State Specialty Description  \
# 0                  21502.0                   MD     Internal Medicine
# 1                  43623.0                   OH        Anesthesiology
# 2                  89403.0                   NV               Dentist
# 3                  91744.0                   CA               Dentist
# 4                  37243.0                   TN    Nurse Practitioner
#
#    Total Claim Count  Opioid Claim Count  Opioid Prescribing Rate  \
# 0                825                38.0                 4.606061
# ...

# %%
#drop last two columns: Long Acting Opioid Claims and Long Acting Opioid Prescribing Rate
op_prescriber15 = op_prescriber15.drop(columns=['Long-Acting Opioid Claims','Long-Acting Opioid Prescribing Rate'])
op_prescriber15.head()
# Out:
#           NPI NPPES Provider Last Name NPPES Provider First Name  \
# 0  1003000126                ENKESHAFI                   ARDALAN
# 1  1003000142                   KHALIL                    RASHID
# 2  1003000167                  ESCOBAR                     JULIO
# 3  1003000175            REYES-VASQUEZ                   BELINDA
# 4  1003000282                BLAKEMORE                     ROSIE
#
#    NPPES Provider ZIP Code NPPES Provider State Specialty Description  \
# 0                  21502.0                   MD     Internal Medicine
# 1                  43623.0                   OH        Anesthesiology
# 2                  89403.0                   NV               Dentist
# 3                  91744.0                   CA               Dentist
# 4                  37243.0                   TN    Nurse Practitioner
#
#    Total Claim Count  Opioid Claim Count  Opioid Prescribing Rate
# 0                825                38.0                 4.606061
# ...

# %%
#renamed columns
op_prescriber15 = op_prescriber15.rename(columns={'NPPES Provider Last Name':'Provider Last Name','NPPES Provider First Name':'Provider First Name','NPPES Provider ZIP Code':'Zip Code','NPPES Provider State':'State','Specialty Description':'Specialty'})
op_prescriber15.head()
# Out:
#           NPI Provider Last Name Provider First Name  Zip Code State  \
# 0  1003000126          ENKESHAFI             ARDALAN   21502.0    MD
# 1  1003000142             KHALIL              RASHID   43623.0    OH
# 2  1003000167            ESCOBAR               JULIO   89403.0    NV
# 3  1003000175      REYES-VASQUEZ             BELINDA   91744.0    CA
# 4  1003000282          BLAKEMORE               ROSIE   37243.0    TN
#
#             Specialty  Total Claim Count  Opioid Claim Count  \
# 0   Internal Medicine                825                38.0
# 1      Anesthesiology               1757               847.0
# 2             Dentist                 43                16.0
# 3             Dentist                 15                 0.0
# 4  Nurse Practitioner                114                21.0
#
#    Opioid Prescribing Rate
# 0                 4.606061
# 1                48.207171
# 2                37.209302
# 3                 0.000000
# 4                18.421053

# %%
#Opiate Prescribers-2016 data frame
op_prescriber16.head()
# Out:
#           NPI NPPES Provider Last Name NPPES Provider First Name  \
# 0  1003000126                ENKESHAFI                   ARDALAN
# 1  1003000142                   KHALIL                    RASHID
# 2  1003000167                  ESCOBAR                     JULIO
# 3  1003000282                BLAKEMORE                     ROSIE
# 4  1003000407                  GIRARDI                     DAVID
#
#    NPPES Provider ZIP Code NPPES Provider State Specialty Description  \
# 0                  21502.0                   MD     Internal Medicine
# 1                  43623.0                   OH        Anesthesiology
# 2                  89403.0                   NV               Dentist
# 3                  37243.0                   TN    Nurse Practitioner
# 4                  15825.0                   PA       Family Practice
#
#    Total Claim Count  Opioid Claim Count  Opioid Prescribing Rate  \
# 0                545                23.0                 4.220183
# ...

# %%
#drop last two columns: Long Acting Opioid Claims and Long Acting Opioid Prescribing Rate
op_prescriber16 = op_prescriber16.drop(columns=['Long-Acting Opioid Claims','Long-Acting Opioid Prescribing Rate'])
op_prescriber16.head()
# Out:
#           NPI NPPES Provider Last Name NPPES Provider First Name  \
# 0  1003000126                ENKESHAFI                   ARDALAN
# 1  1003000142                   KHALIL                    RASHID
# 2  1003000167                  ESCOBAR                     JULIO
# 3  1003000282                BLAKEMORE                     ROSIE
# 4  1003000407                  GIRARDI                     DAVID
#
#    NPPES Provider ZIP Code NPPES Provider State Specialty Description  \
# 0                  21502.0                   MD     Internal Medicine
# 1                  43623.0                   OH        Anesthesiology
# 2                  89403.0                   NV               Dentist
# 3                  37243.0                   TN    Nurse Practitioner
# 4                  15825.0                   PA       Family Practice
#
#    Total Claim Count  Opioid Claim Count  Opioid Prescribing Rate
# 0                545                23.0                 4.220183
# ...

# %%
#renamed columns
op_prescriber16 = op_prescriber16.rename(columns={'NPPES Provider Last Name':'Provider Last Name','NPPES Provider First Name':'Provider First Name','NPPES Provider ZIP Code':'Zip Code','NPPES Provider State':'State','Specialty Description':'Specialty'})
op_prescriber16.head()
# Out:
#           NPI Provider Last Name Provider First Name  Zip Code State  \
# 0  1003000126          ENKESHAFI             ARDALAN   21502.0    MD
# 1  1003000142             KHALIL              RASHID   43623.0    OH
# 2  1003000167            ESCOBAR               JULIO   89403.0    NV
# 3  1003000282          BLAKEMORE               ROSIE   37243.0    TN
# 4  1003000407            GIRARDI               DAVID   15825.0    PA
#
#             Specialty  Total Claim Count  Opioid Claim Count  \
# 0   Internal Medicine                545                23.0
# 1      Anesthesiology               1733               941.0
# 2             Dentist                 49                11.0
# 3  Nurse Practitioner                146                 NaN
# 4     Family Practice               2225                17.0
#
#    Opioid Prescribing Rate
# 0                 4.220183
# 1                54.298904
# 2                22.448980
# 3                      NaN
# 4                 0.764045

# %%
#Physician Ratings 2016
phys_ratings16.head()
# Out:
#           NPI    PAC ID Last Name First Name Measure Identifier  \
# 0  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_110_1
# 1  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_111_1
# 2  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_113_1
# 3  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_130_1
# 4  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_226_1
#
#                                        Measure Title Inverse Measure  \
# 0  Preventive Care and Screening: Influenza Immun...               N
# 1      Pneumonia Vaccination Status for Older Adults               N
# 2                        Colorectal Cancer Screening               N
# 3  Documentation of Current Medications in the Me...               N
# 4  Preventive Care and Screening: Tobacco Use: Sc...               N
#
#    Measure Performance Rate  Denominator Count Collection Type  \
# 0                        20                 71             CLM
# ...

# %%
#dropped 'inverse measure','collection type', and 'reported on pc live site'
ratings2016 = phys_ratings16.drop(columns=['PAC ID','Inverse Measure','Collection Type','Reported on PC Live Site'])
ratings2016.head()
# Out:
#           NPI Last Name First Name Measure Identifier  \
# 0  1508823618   GRIFFIN      DAVID      PQRS_EP_110_1
# 1  1508823618   GRIFFIN      DAVID      PQRS_EP_111_1
# 2  1508823618   GRIFFIN      DAVID      PQRS_EP_113_1
# 3  1508823618   GRIFFIN      DAVID      PQRS_EP_130_1
# 4  1508823618   GRIFFIN      DAVID      PQRS_EP_226_1
#
#                                        Measure Title  \
# 0  Preventive Care and Screening: Influenza Immun...
# 1      Pneumonia Vaccination Status for Older Adults
# 2                        Colorectal Cancer Screening
# 3  Documentation of Current Medications in the Me...
# 4  Preventive Care and Screening: Tobacco Use: Sc...
#
#    Measure Performance Rate  Denominator Count
# 0                        20                 71
# 1                        41                 90
# 2                        29                 70
# 3                        91                255
# 4                        98                104

# %%
phys_ratings15.head()
# Out:
#           NPI    PAC ID Last Name First Name Measure Identifier  \
# 0  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_110_1
# 1  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_111_1
# 2  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_112_1
# 3  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_113_1
# 4  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_128_1
#
#                                        Measure Title Inverse Measure  \
# 0  Preventive Care and Screening: Influenza Immun...               N
# 1      Pneumonia Vaccination Status for Older Adults               N
# 2                            Breast Cancer Screening               N
# 3                        Colorectal Cancer Screening               N
# 4  Preventive Care and Screening: Body Mass Index...               N
#
#    Measure Performance Rate Reporting Mechanism Reported on PC Live Site
# 0                        21                 CLM                        Y
# ...

# %%
phys_ratings15['Year'] = 2015

# %%
phys_ratings15.head()
# Out:
#           NPI    PAC ID Last Name First Name Measure Identifier  \
# 0  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_110_1
# 1  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_111_1
# 2  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_112_1
# 3  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_113_1
# 4  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_128_1
#
#                                        Measure Title Inverse Measure  \
# 0  Preventive Care and Screening: Influenza Immun...               N
# 1      Pneumonia Vaccination Status for Older Adults               N
# 2                            Breast Cancer Screening               N
# 3                        Colorectal Cancer Screening               N
# 4  Preventive Care and Screening: Body Mass Index...               N
#
#    Measure Performance Rate Reporting Mechanism Reported on PC Live Site  Year
# 0                        21                 CLM                        Y  2015
# ...

# %%
physratings15 = phys_ratings15[['NPI','PAC ID','Year']]
physratings15.head()
# Out:
#           NPI    PAC ID  Year
# 0  1508823618  42100117  2015
# 1  1508823618  42100117  2015
# 2  1508823618  42100117  2015
# 3  1508823618  42100117  2015
# 4  1508823618  42100117  2015

# %%
physratings15clean = physratings15.drop_duplicates(keep=False)

# %%
physratings15clean.head()
# Out:
#            NPI    PAC ID  Year
# 11  1154338044  42100190  2015
# 12  1982641247  42100273  2015
# 19  1033197512  42100547  2015
# 20  1447242219  42100687  2015
# 23  1881799146  42101156  2015

# %%
op_prescriber15.describe()
# Out:
#                 NPI      Zip Code  Total Claim Count  Opioid Claim Count  \
# count  1.102253e+06  1.102191e+06       1.102253e+06       788434.000000
# mean   1.499733e+09  4.804722e+04       1.312845e+03           99.576332
# std    2.879199e+08  3.034006e+04       3.149188e+03          311.294988
# min    1.003000e+09  0.000000e+00       1.100000e+01            0.000000
# 25%    1.245660e+09  2.120100e+04       5.300000e+01            0.000000
# 50%    1.497967e+09  4.503600e+04       1.970000e+02           20.000000
# 75%    1.740692e+09  7.671000e+04       9.920000e+02           75.000000
# max    1.993000e+09  9.992900e+04       2.951030e+05        22627.000000
#
#        Opioid Prescribing Rate
# count            788434.000000
# mean                 11.481685
# std                  17.653588
# min                   0.000000
# 25%                   0.000000
# 50%                   3.333333
# 75%                  15.434783
# max                 100.000000

# %%
#here we wanted to drop the rows with missing values, specifically we knew that many fields were missing the opioid claim column
op_prescriber15clean = op_prescriber15.dropna(axis=0, how='any')
op_prescriber15clean.describe()
# Out:
#                 NPI       Zip Code  Total Claim Count  Opioid Claim Count  \
# count  7.883500e+05  788350.000000      788350.000000       788350.000000
# mean   1.499459e+09   48167.322364        1634.435642           99.583408
# std    2.878226e+08   30221.416054        3587.776354          311.308274
# min    1.003000e+09       0.000000          11.000000            0.000000
# 25%    1.245643e+09   21237.000000          71.000000            0.000000
# 50%    1.497950e+09   44718.000000         272.000000           20.000000
# 75%    1.740609e+09   76508.000000        1452.000000           75.000000
# max    1.993000e+09   99929.000000      295103.000000        22627.000000
#
#        Opioid Prescribing Rate
# count            788350.000000
# mean                 11.482064
# std                  17.653566
# min                   0.000000
# 25%                   0.000000
# 50%                   3.333333
# 75%                  15.436242
# max                 100.000000

# %%
op_prescriber16.describe()
# Out:
#                 NPI      Zip Code  Total Claim Count  Opioid Claim Count  \
# count  1.131550e+06  1.131496e+06       1.131550e+06       812675.000000
# mean   1.499842e+09  4.806819e+04       1.308800e+03           95.721827
# std    2.879109e+08  3.029546e+04       3.147395e+03          313.751936
# min    1.003000e+09  0.000000e+00       1.100000e+01            0.000000
# 25%    1.245689e+09  2.120100e+04       5.400000e+01            0.000000
# 50%    1.497973e+09  4.503900e+04       2.000000e+02           19.000000
# 75%    1.740699e+09  7.657400e+04       1.000000e+03           69.000000
# max    1.993000e+09  9.992900e+04       3.242090e+05        21767.000000
#
#        Opioid Prescribing Rate
# count            812675.000000
# mean                 10.932238
# std                  17.386558
# min                   0.000000
# 25%                   0.000000
# 50%                   2.872671
# 75%                  14.080460
# max                 100.000000

# %%
#here we wanted to drop the rows with missing values, specifically we knew that many fields were missing the opioid claim column
op_prescriber16clean = op_prescriber16.dropna(axis=0, how='any')
op_prescriber16clean.describe()
# Out:
#                 NPI       Zip Code  Total Claim Count  Opioid Claim Count  \
# count  8.125870e+05  812587.000000      812587.000000       812587.000000
# mean   1.499614e+09   48120.618094        1621.663161           95.728647
# std    2.878957e+08   30176.262817        3578.562794          313.766038
# min    1.003000e+09       0.000000          11.000000            0.000000
# 25%    1.245670e+09   21239.000000          72.000000            0.000000
# 50%    1.497952e+09   44622.000000         273.000000           19.000000
# 75%    1.740681e+09   76424.000000        1450.000000           69.000000
# max    1.993000e+09   99929.000000      324209.000000        21767.000000
#
#        Opioid Prescribing Rate
# count            812587.000000
# mean                 10.932670
# std                  17.386652
# min                   0.000000
# 25%                   0.000000
# 50%                   2.873160
# 75%                  14.084418
# max                 100.000000

# %%
op_prescriber15_merged = op_prescriber15clean.merge(physratings15clean, on="NPI", how="outer")
op_prescriber15_merged.head()
# Out:
#           NPI Provider Last Name Provider First Name  Zip Code State  \
# 0  1003000126          ENKESHAFI             ARDALAN   21502.0    MD
# 1  1003000142             KHALIL              RASHID   43623.0    OH
# 2  1003000167            ESCOBAR               JULIO   89403.0    NV
# 3  1003000175      REYES-VASQUEZ             BELINDA   91744.0    CA
# 4  1003000282          BLAKEMORE               ROSIE   37243.0    TN
#
#             Specialty  Total Claim Count  Opioid Claim Count  \
# 0   Internal Medicine              825.0                38.0
# 1      Anesthesiology             1757.0               847.0
# 2             Dentist               43.0                16.0
# 3             Dentist               15.0                 0.0
# 4  Nurse Practitioner              114.0                21.0
#
#    Opioid Prescribing Rate  PAC ID  Year
# 0                 4.606061     NaN   NaN
# 1                48.207171     NaN   NaN
# 2                37.209302     NaN   NaN
# ...

# %%
#here we note that we have way more NPI values than PAC ID so we will need to drop PAC ID again 
op_prescriber15_merged.describe()
# Out:
#                 NPI       Zip Code  Total Claim Count  Opioid Claim Count  \
# count  8.343370e+05  788350.000000      788350.000000       788350.000000
# mean   1.499403e+09   48167.322364        1634.435642           99.583408
# std    2.878216e+08   30221.416054        3587.776354          311.308274
# min    1.003000e+09       0.000000          11.000000            0.000000
# 25%    1.245640e+09   21237.000000          71.000000            0.000000
# 50%    1.497946e+09   44718.000000         272.000000           20.000000
# 75%    1.740597e+09   76508.000000        1452.000000           75.000000
# max    1.993000e+09   99929.000000      295103.000000        22627.000000
#
#        Opioid Prescribing Rate        PAC ID     Year
# count            788350.000000  7.457100e+04  74571.0
# mean                 11.482064  4.990581e+09   2015.0
# std                  17.653566  2.871375e+09      0.0
# min                   0.000000  4.210019e+07   2015.0
# ...

# %%
op_prescriber15_final = op_prescriber15_merged.dropna(axis=0, how='any')
op_prescriber15_final.head()
# Out:
#            NPI Provider Last Name Provider First Name  Zip Code State  \
# 5   1003000407            GIRARDI               DAVID   15825.0    PA
# 22  1003001785              JONES              JACLYN   33765.0    FL
# 37  1003002932            GALUSKA             MICHAEL   92055.0    CA
# 39  1003003856           SANTIAGO             CYNTHIA   11776.0    NY
# 51  1003005109            FETTMAN            NICHOLAS   93030.0    CA
#
#              Specialty  Total Claim Count  Opioid Claim Count  \
# 5      Family Practice             1388.0                26.0
# 22  Orthopedic Surgery              193.0                43.0
# 37  Emergency Medicine               97.0                20.0
# 39     Family Practice             2741.0                28.0
# 51      Otolaryngology              870.0                50.0
#
#     Opioid Prescribing Rate        PAC ID    Year
# 5                  1.873199  2.769664e+09  2015.0
# 22                22.279793  5.799872e+09  2015.0
# ...

# %%
op_prescriber15_final["Specialty"].unique()
# Out:
# array(['Family Practice', 'Orthopedic Surgery', 'Emergency Medicine',
#        'Otolaryngology', 'Internal Medicine', 'Anesthesiology',
#        'Nurse Practitioner', 'General Surgery',
#        'Physical Medicine and Rehabilitation', 'Neurosurgery', 'Urology',
#        'Physician Assistant', 'Hematology/Oncology', 'Optometry',
#        'Ophthalmology', 'Pulmonary Disease', 'Neurology', 'Cardiology',
#        'Gastroenterology', 'Allergy/Immunology', 'Endocrinology',
#        'Thoracic Surgery', 'Plastic and Reconstructive Surgery',
#        'Diagnostic Radiology', 'Podiatry', 'Medical Oncology',
#        'Pain Management', 'Colorectal Surgery (formerly proctology)',
#        'Obstetrics/Gynecology', 'Interventional Cardiology',
#        'Interventional Pain Management', 'Psychiatry',
#        'Certified Nurse Midwife', 'Nephrology', 'Vascular Surgery',
#        'Rheumatology', 'Osteopathic Manipulative Medicine',
# ...

# %%
op_prescriber15_final.describe()
# Out:
#                 NPI      Zip Code  Total Claim Count  Opioid Claim Count  \
# count  2.858400e+04  28584.000000       28584.000000        28584.000000
# mean   1.499944e+09  50234.655926        1987.508256          135.058039
# std    2.866188e+08  28997.742541        4077.148108          389.312817
# min    1.003000e+09    674.000000          11.000000            0.000000
# 25%    1.255365e+09  28207.000000         166.000000           14.000000
# 50%    1.497956e+09  47124.000000         373.000000           40.000000
# 75%    1.740425e+09  77030.000000        1722.000000          103.000000
# max    1.992999e+09  99801.000000       79676.000000        15163.000000
#
#        Opioid Prescribing Rate        PAC ID     Year
# count             28584.000000  2.858400e+04  28584.0
# mean                 14.066292  4.959390e+09   2015.0
# std                  16.724986  2.859905e+09      0.0
# min                   0.000000  4.210019e+07   2015.0
# ...

# %%
saved_specialties = ['Family Practice', 'Emergency Medicine','Internal Medicine',\
                     'Physical Medicine and Rehabilitation', 'Neurology',\
                     'Pain Management', 'Psychiatry','General Practice',\
                     'Neuropsychiatry', 'Addiction Medicine']

# %%
op_prescriber15_final1 = op_prescriber15_final.loc[(op_prescriber15_final["Specialty"] == 'Family Practice') | \
                                                   (op_prescriber15_final["Specialty"] == 'Emergency Medicine') | \
                                                   (op_prescriber15_final["Specialty"] == 'Internal Medicine') | \
                                                   (op_prescriber15_final["Specialty"] == 'Physical Medicine and Rehabilitation') | \
                                                   (op_prescriber15_final["Specialty"] == 'Neurology') | \
                                                   (op_prescriber15_final["Specialty"] == 'Pain Management') | \
                                                   (op_prescriber15_final["Specialty"] == 'Psychiatry') | \
                                                   (op_prescriber15_final["Specialty"] == 'General Practice') | \
                                                   (op_prescriber15_final["Specialty"] == 'Neuropsychiatry') | \
                                                   (op_prescriber15_final["Specialty"] == 'Addiction Medicine'),:]

# %%
op_prescriber15_final1.describe()
# Out:
#                 NPI      Zip Code  Total Claim Count  Opioid Claim Count  \
# count  1.485300e+04  14853.000000       14853.000000        14853.000000
# mean   1.497864e+09  52352.024776        2927.645661          175.726789
# std    2.867357e+08  29257.026688        5172.799779          380.625909
# min    1.003000e+09    680.000000          11.000000            0.000000
# 25%    1.255338e+09  30005.000000         221.000000           27.000000
# 50%    1.497785e+09  48336.000000         456.000000           59.000000
# 75%    1.740265e+09  78701.000000        3614.000000          153.000000
# max    1.992999e+09  99801.000000       79676.000000        15163.000000
#
#        Opioid Prescribing Rate        PAC ID     Year
# count             14853.000000  1.485300e+04  14853.0
# mean                 13.651318  4.955473e+09   2015.0
# std                  12.205777  2.858699e+09      0.0
# min                   0.000000  4.210019e+07   2015.0
# ...

# %%
#double check that our specialty columns match
op_prescriber15_final1.Specialty.unique()
# Out:
# array(['Family Practice', 'Emergency Medicine', 'Internal Medicine',
#        'Physical Medicine and Rehabilitation', 'Neurology',
#        'Pain Management', 'Psychiatry', 'General Practice',
#        'Neuropsychiatry', 'Addiction Medicine'], dtype=object)

# %%
###
op_prescriber15_final1.to_csv(output1, encoding="utf-8", index=False)

# %%
phys_ratings16['Year'] = 2016
phys_ratings16.head()
# Out:
#           NPI    PAC ID Last Name First Name Measure Identifier  \
# 0  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_110_1
# 1  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_111_1
# 2  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_113_1
# 3  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_130_1
# 4  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_226_1
#
#                                        Measure Title Inverse Measure  \
# 0  Preventive Care and Screening: Influenza Immun...               N
# 1      Pneumonia Vaccination Status for Older Adults               N
# 2                        Colorectal Cancer Screening               N
# 3  Documentation of Current Medications in the Me...               N
# 4  Preventive Care and Screening: Tobacco Use: Sc...               N
#
#    Measure Performance Rate  Denominator Count Collection Type  \
# 0                        20                 71             CLM
# ...

# %%
physratings16 = phys_ratings16[['NPI','PAC ID','Year']]
physratings16.head()
# Out:
#           NPI    PAC ID  Year
# 0  1508823618  42100117  2016
# 1  1508823618  42100117  2016
# 2  1508823618  42100117  2016
# 3  1508823618  42100117  2016
# 4  1508823618  42100117  2016

# %%
physratings16clean = physratings16.drop_duplicates(keep=False)
physratings16clean.head()
# Out:
#            NPI    PAC ID  Year
# 7   1154338044  42100190  2016
# 20  1396828901  42101651  2016
# 21  1225135908  42101685  2016
# 30  1992762215  42102246  2016
# 31  1871532614  42102279  2016

# %%
#merge 16 data on NPI, and using outer to include all data
op_prescriber16_merged = op_prescriber16clean.merge(physratings16clean, on="NPI", how="outer")
op_prescriber16_merged.head()
# Out:
#           NPI Provider Last Name Provider First Name  Zip Code State  \
# 0  1003000126          ENKESHAFI             ARDALAN   21502.0    MD
# 1  1003000142             KHALIL              RASHID   43623.0    OH
# 2  1003000167            ESCOBAR               JULIO   89403.0    NV
# 3  1003000407            GIRARDI               DAVID   15825.0    PA
# 4  1003000480          ROTHCHILD               KEVIN   80045.0    CO
#
#            Specialty  Total Claim Count  Opioid Claim Count  \
# 0  Internal Medicine              545.0                23.0
# 1     Anesthesiology             1733.0               941.0
# 2            Dentist               49.0                11.0
# 3    Family Practice             2225.0                17.0
# 4    General Surgery               71.0                13.0
#
#    Opioid Prescribing Rate  PAC ID  Year
# 0                 4.220183     NaN   NaN
# 1                54.298904     NaN   NaN
# 2                22.448980     NaN   NaN
# ...

# %%
op_prescriber16_final = op_prescriber16_merged.dropna(axis=0, how='any')
op_prescriber16_final.head()
# Out:
#             NPI Provider Last Name Provider First Name  Zip Code State  \
# 60   1003006503             JEGEDE          OLUGBEMIGA   48503.0    MI
# 75   1003007469              OZUNA             EDUARDO   76542.0    TX
# 215  1003015686              BLUME             DEBORAH    1199.0    MA
# 302  1003021205           AMUNDSEN                DEAN   93010.0    CA
# 312  1003021973              ZHANG           ALEXANDRA   44320.0    OH
#
#                Specialty  Total Claim Count  Opioid Claim Count  \
# 60     Internal Medicine             2029.0               153.0
# 75        Anesthesiology             3421.0              2547.0
# 215  Physician Assistant             2160.0                41.0
# 302            Optometry              376.0                 0.0
# 312          Dermatology              570.0               100.0
#
#      Opioid Prescribing Rate        PAC ID    Year
# 60                  7.540660  1.951572e+09  2016.0
# ...

# %%
op_prescriber16_final.describe()
# Out:
#                 NPI      Zip Code  Total Claim Count  Opioid Claim Count  \
# count  2.057300e+04  20573.000000       20573.000000        20573.000000
# mean   1.499194e+09  46911.155106        2632.347300          168.237107
# std    2.877764e+08  28686.363387        4775.172833          503.078464
# min    1.003007e+09    612.000000          11.000000            0.000000
# 25%    1.245565e+09  25301.000000         223.000000            0.000000
# 50%    1.497990e+09  40223.000000         680.000000           32.000000
# 75%    1.740483e+09  75231.000000        2984.000000          123.000000
# max    1.992993e+09  99801.000000      131567.000000        15462.000000
#
#        Opioid Prescribing Rate        PAC ID     Year
# count             20573.000000  2.057300e+04  20573.0
# mean                 10.974768  4.936086e+09   2016.0
# std                  18.035174  2.856249e+09      0.0
# min                   0.000000  4.210019e+07   2016.0
# ...

# %%
op_prescriber16_final1 = op_prescriber16_final.loc[(op_prescriber16_final["Specialty"] == 'Family Practice') | \
                                                   (op_prescriber16_final["Specialty"] == 'Emergency Medicine') | \
                                                   (op_prescriber16_final["Specialty"] == 'Internal Medicine') | \
                                                   (op_prescriber16_final["Specialty"] == 'Physical Medicine and Rehabilitation') | \
                                                   (op_prescriber16_final["Specialty"] == 'Neurology') | \
                                                   (op_prescriber16_final["Specialty"] == 'Pain Management') | \
                                                   (op_prescriber16_final["Specialty"] == 'Psychiatry') | \
                                                   (op_prescriber16_final["Specialty"] == 'General Practice') | \
                                                   (op_prescriber16_final["Specialty"] == 'Neuropsychiatry') | \
                                                   (op_prescriber16_final["Specialty"] == 'Addiction Medicine'),:]

# %%
op_prescriber16_final1.Specialty.unique()
# Out:
# array(['Internal Medicine', 'Family Practice',
#        'Physical Medicine and Rehabilitation', 'Neurology', 'Psychiatry',
#        'Emergency Medicine', 'General Practice', 'Pain Management',
#        'Neuropsychiatry', 'Addiction Medicine'], dtype=object)

# %%
op_prescriber16_final1.describe()
# Out:
#                 NPI      Zip Code  Total Claim Count  Opioid Claim Count  \
# count  8.230000e+03   8230.000000        8230.000000         8230.000000
# mean   1.500904e+09  47352.179708        4784.229162          252.877035
# std    2.878875e+08  29088.490935        6517.829504          553.005548
# min    1.003007e+09    612.000000          11.000000            0.000000
# 25%    1.245504e+09  23805.000000         426.250000           23.000000
# 50%    1.508833e+09  40216.000000        2483.000000           71.000000
# 75%    1.740595e+09  76104.000000        6814.250000          265.000000
# max    1.992972e+09  99801.000000      131567.000000        15462.000000
#
#        Opioid Prescribing Rate        PAC ID    Year
# count              8230.000000  8.230000e+03  8230.0
# mean                  7.262434  4.983135e+09  2016.0
# std                  10.919184  2.848711e+09     0.0
# min                   0.000000  4.210019e+07  2016.0
# ...

# %%
##send to new csv
op_prescriber16_final1.to_csv(output2, encoding="utf-8", index=False)
