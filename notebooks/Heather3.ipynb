# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import os
import sys
import numpy as np
import seaborn as sns
import scipy.stats as stats

csv0 = '../Presentation/clean/clean_od15.csv'
csv1 = '../Presentation/clean/clean_od16.csv'
csv2 = '../Presentation/clean/op_final_15.csv'
csv3 = '../Presentation/clean/op_final_16.csv'
csv4 = '../Presentation/clean/PAC_Scores_2015.csv'
csv5 = '../Presentation/clean/PAC_Scores_2016_f.csv'
csv7 = '../Presentation/clean/op_pac_final_15.csv'
csv8 = '../Presentation/clean/op_pac_final_16.csv'
csv9 = '../Presentation/clean/state_op_final_15.csv'
csv10 = '../Presentation/clean/state_op_final_16.csv'
csv11 = '../Presentation/Clean/merged_ratings_prescribed_15'
csv12 = '../Presentation/Clean/merged_ratings_prescribed_16'

clean_od_2015 = pd.read_csv(csv0)
clean_od_2016 = pd.read_csv(csv1)
op_final_15 = pd.read_csv(csv2)
op_final_16 = pd.read_csv(csv3)
PAC_Scores_2015 = pd.read_csv(csv4)
PAC_Scores_2016 = pd.read_csv(csv5)
op_pac_final_15 = pd.read_csv(csv7)
op_pac_final_16 = pd.read_csv(csv8)
state_op_final_15 = pd.read_csv(csv9)
state_op_final_16 = pd.read_csv(csv10)
merged15 = pd.read_csv(csv11)
merged16 = pd.read_csv(csv12)

# %%
clean_od_2015.head()
# Out:
#    Year State  Year.1     Month  Total Deaths  Drug Deaths
# 0  2015    AK    2015   January          4034          126
# 1  2015    AK    2015  February          4084          127
# 2  2015    AK    2015     March          4101          125
# 3  2015    AK    2015     April          4133          126
# 4  2015    AK    2015       May          4196          125

# %%
plt.figure(figsize=(30,10))
sns.set_style('darkgrid')
plt.title('Drug Related Deaths 2015')
sns.set_style('darkgrid')
sns.set_context('notebook',font_scale=1)
sns.barplot(x='Month',y='Drug Deaths',data=clean_od_2015)

plt.savefig('../Presentation/graphs/drugdeaths2015.png')
# Out:
# /Users/HeatherTrinh/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(40,10))
plt.title('Drug Deaths by State 2015')
sns.set_style('darkgrid')
sns.set_context('poster',font_scale=1)
sns.barplot(x='State',y=np.arange(0,10000,2),data=clean_od_2015)

# %%
clean_od_2016.head()
# Out:
#    Year State  Year.1     Month  Total Deaths  Drug Deaths
# 0  2016    AK    2016   January          4213          126
# 1  2016    AK    2016  February          4198          128
# 2  2016    AK    2016     March          4230          125
# 3  2016    AK    2016     April          4262          132
# 4  2016    AK    2016       May          4241          140

# %%
plt.figure(figsize=(30,10))
sns.set_style('darkgrid')
plt.title('Drug Related Deaths 2016')
sns.set_context('poster',font_scale=1)
sns.barplot(x='Month',y='Drug Deaths',data=clean_od_2016)

#plt.savefig('../Presentation/graphs/drugdeaths2016.png')

# %%
plt.figure(figsize=(30,10))
sns.set_style('darkgrid')
plt.title('Drug Related Deaths 2016')
sns.set_context('poster',font_scale=1)
sns.barplot(x='State',y='Drug Deaths',data=clean_od_2016)

# %%
op_final_15.head()
# Out:
#           NPI Provider Last Name Provider First Name  Zip Code State  \
# 0  1003000407            GIRARDI               DAVID   15825.0    PA
# 1  1003002932            GALUSKA             MICHAEL   92055.0    CA
# 2  1003003856           SANTIAGO             CYNTHIA   11776.0    NY
# 3  1003006503             JEGEDE          OLUGBEMIGA   48503.0    MI
# 4  1003007295            UZOWULU              OBINNA   78261.0    TX
#
#             Specialty  Total Claim Count  Opioid Claim Count  \
# 0     Family Practice             1388.0                26.0
# 1  Emergency Medicine               97.0                20.0
# 2     Family Practice             2741.0                28.0
# 3   Internal Medicine             1606.0                86.0
# 4     Family Practice              237.0                21.0
#
#    Opioid Prescribing Rate        PAC ID    Year
# 0                 1.873199  2.769664e+09  2015.0
# 1                20.618557  9.739345e+09  2015.0
# ...

# %%
#op_final_15 state vs opioid claim count
plt.figure(figsize=(40,10))
plt.title('Opioid Claims by State 2015')
sns.set_style('darkgrid')
sns.set_context('poster')
sns.barplot(x=op_final_15['State'].sort_values(ascending=True),y=op_final_15['Opioid Claim Count'])

plt.savefig('../Presentation/graphs/opioid_claims_state_2015.png')

# %%
op_final_16.head()
# Out:
#           NPI Provider Last Name Provider First Name  Zip Code State  \
# 0  1003006503             JEGEDE          OLUGBEMIGA   48503.0    MI
# 1  1003046897          HARFOUCHE               KARIM   33467.0    FL
# 2  1003047564          MURUKESAN              VIDHYA   68131.0    NE
# 3  1003048687              KOLLU               VIDYA   48532.0    MI
# 4  1003070558             URAZOV               PETER   11772.0    NY
#
#            Specialty  Total Claim Count  Opioid Claim Count  \
# 0  Internal Medicine             2029.0               153.0
# 1  Internal Medicine             2873.0               131.0
# 2  Internal Medicine             1050.0                25.0
# 3  Internal Medicine              252.0                20.0
# 4    Family Practice              982.0                24.0
#
#    Opioid Prescribing Rate        PAC ID    Year
# 0                 7.540660  1.951572e+09  2016.0
# 1                 4.559694  1.153578e+09  2016.0
# ...

# %%
#op_final_16 state vs opioid claim count
plt.figure(figsize=(40,10))
sns.set_style('darkgrid')
sns.set_context('poster')
plt.title('Opioid Claims by State 2016')
sns.barplot(x=op_final_16['State'].sort_values(ascending=True),y=op_final_16['Opioid Prescribing Rate'])

plt.savefig('../Presentation/graphs/opioid_claims_state_2016.png')

# %%
#prescribing rate by specialty
plt.figure(figsize=(40,10))
sns.set_style('darkgrid')
plt.title('Prescribing Rate by Specialty')
sns.set_context('notebook',font_scale=1)
sns.barplot(x=op_final_16['Specialty'],y=op_final_16['Opioid Prescribing Rate'])

#plt.savefig('../Presentation/graphs/specialty_prescribing_rate.png')

# %%
state_op_final_15.head()
# Out:
#   State  Total Claim Count  Opioid Claim Count  Opioid Prescribing Rate
# 0    AP              103.0                21.0                    20.39
# 1    ID            60229.0              7704.0                    12.79
# 2    ZZ              251.0                26.0                    10.36
# 3    MT            26480.0              2442.0                     9.22
# 4    DE            24076.0              2085.0                     8.66

# %%
x_axis=state_op_final_15['Opioid Prescribing Rate']
y_axis=clean_od_2015['Drug Deaths']

# %%
#drug deaths vs opioid claim count
plt.figure(figsize=(10,6))
plt.title('Drug Deaths vs Opioid Prescribing Rate 2015')
sns.set_context('poster',font_scale=1.0,rc={"lines.linewidth":1.5})
sns.set_style('darkgrid')
sns.scatterplot(x=x_axis, y=y_axis)

# %%
merged15.head()
# Out:
#      PAC ID  Total Claim Count  Opioid Claim Count  Opioid Prescribing Rate  \
# 0  42100190              241.0                68.0                    28.22
# 1  42101156              620.0                38.0                     6.13
# 2  42102618              496.0               231.0                    46.57
# 3  42104929            11309.0               346.0                     3.06
# 4  42200099             2141.0                67.0                     3.13
#
#   State  Measure Performance Rate
# 0    MI                      85.0
# 1    NV                      86.0
# 2    CA                     100.0
# 3    FL                     100.0
# 4    FL                     100.0

# %%
#state vs opioid claim count
plt.figure(figsize=(40,10))
sns.set_style('darkgrid')
sns.set_context('poster')
plt.title('Opioid Claim Count by State')
sns.barplot(x=merged15['State'].sort_values(ascending=True),y=merged15['Opioid Claim Count'])

# %%
#state vs opioid claim count
plt.figure(figsize=(40,10))
sns.set_style('darkgrid')
sns.set_context('poster')
plt.title('Opioid Prescrbing Rate by State 2015')
sns.barplot(x=merged15['State'].sort_values(ascending=True),y=merged15['Opioid Prescribing Rate'])

plt.savefig('../Presentation/graphs/specialty_prescribing_rate.png')

# %%
#total claim count vs measure performance rate
plt.figure(figsize=(10,6))
plt.title('Total Claim Count vs Measure Performance Rate')
sns.set_context('talk',font_scale=1.0,rc={"lines.linewidth":1.5})
sns.set_style('darkgrid')
sns.color_palette("husl")
sns.scatterplot(x='Measure Performance Rate', y='Total Claim Count',data=merged15)

# %%
#measure performance rate vs opioid prescribing rate
plt.figure(figsize=(10,6))

sns.set_context('talk',font_scale=1.0,rc={"lines.linewidth":1.5})
sns.set_style('darkgrid')
sns.scatterplot(x=merged15['Opioid Prescribing Rate'], y=merged15['Measure Performance Rate'])

# %%
#opioid prescribing rate vs measure performance rate
plt.figure(figsize=(10,6))
plt.title('Opioid Prescribing Rate vs Measure Performance Rate')
sns.set_context('talk',font_scale=1.0,rc={"lines.linewidth":1.5})
sns.set_style('darkgrid')
sns.scatterplot(x=merged15['Measure Performance Rate'], y=merged15['Opioid Prescribing Rate'])

# %%
plt.figure(figsize=(10,6))
sns.set_style('darkgrid')
plt.title('Opiate Prescribing Rate vs Drug Deaths 2015')
sns.scatterplot(x=clean_od_2015['Drug Deaths'],y=merged15['Opioid Prescribing Rate'])

#clean_od_2015['Drug Deaths']
#merged15['Opioid Prescribing Rate']

# %%
merged16.head()
# Out:
#      PAC ID  Total Claim Count  Opioid Claim Count  Opioid Prescribing Rate  \
# 0  42100190              241.0                77.0                    31.95
# 1  42102618              491.0               226.0                    46.03
# 2  42115404             9227.0                30.0                     0.33
# 3  42123713             4353.0               114.0                     2.62
# 4  42209470             6638.0               136.0                     2.05
#
#   State  Measure Performance Rate
# 0    MI                     96.00
# 1    CA                    100.00
# 2    KY                    100.00
# 3    MN                     45.67
# 4    WI                     95.00

# %%
plt.figure(figsize=(40,10))
sns.set_style('darkgrid')
plt.title('Opioid Prescribing Rate by State')
sns.barplot(x=merged16['State'],y=merged16['Opioid Prescribing Rate'])

# %%
merged16grouped = merged16.groupby('State').sum()
merged16grouped.head()
# Out:
#               PAC ID  Total Claim Count  Opioid Claim Count  \
# State
# AK       40649234297             5268.0               300.0
# AL      333212210840           604222.0             42474.0
# AR      254786050439           343692.0             20223.0
# AZ      416593639999           334031.0             17733.0
# CA     1820267875286          1749494.0             93856.0
#
#        Opioid Prescribing Rate  Measure Performance Rate
# State
# AK                       42.07                    402.00
# AL                      381.80                   5280.33
# AR                      317.83                   4100.98
# AZ                      631.19                   6756.84
# CA                     2911.03                  29187.09

# %%
#grouped by state
plt.figure(figsize=(10,6))
plt.title('Opiate Prescribing Rate vs Measure Performance Rate 2016')
sns.set_style('darkgrid')
sns.regplot(x=merged16grouped['Measure Performance Rate'],y=merged16grouped['Opioid Prescribing Rate'])


plt.savefig('../Presentation/graphs/op_prescribing_rate_vs_performance_rate2016.png')

# %%
merged15grouped = merged15.groupby('State').sum()
#grouped by state
plt.figure(figsize=(10,6))
plt.title('Opiate Prescribing Rate vs Measure Performance Rate 2015')
sns.set_style('darkgrid')
sns.regplot(x=merged15grouped['Measure Performance Rate'],y=merged15grouped['Opioid Prescribing Rate'])

#plt.savefig('../Presentation/graphs/op_prescribing_rate_vs_performance_rate2015.png')

# %%
pop1 = merged15grouped['Measure Performance Rate']
pop2 = merged15grouped['Opioid Prescribing Rate']

# %%
sns.jointplot(pop1, pop2,kind='kde')

plt.savefig('../Presentation/graphs/jointplot_prescribingrate_performancerate_2015.png')

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(pop1, pop2,cmap='Purples')
plt.scatter(pop1, pop2, marker='x', color='black', alpha=0.5)
plt.savefig('../Presentation/graphs/KDEPLOT_with_SCATTER_prescribingrate_performancerate_2015.png')

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance

stats.ttest_ind(pop1, pop2, equal_var = False)
# Out:
# Ttest_indResult(statistic=5.256923542917966, pvalue=2.807166884213625e-06)
