# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import os
import sys

csv1 = '../Presentation/clean/cleaned_overdose.csv'
csv2 = '../Presentation/clean/op_final_15.csv'
csv3 = '../Presentation/clean/op_final_16.csv'
csv4 = '../Presentation/clean/pcgroup_15.csv'
csv5 = '../Presentation/clean/pcgroup_16.csv'

clean_od = pd.read_csv(csv1)
op_final_15 = pd.read_csv(csv2)
op_final_16 = pd.read_csv(csv3)
pcgroup_15 = pd.read_csv(csv4)
pcgroup_16 = pd.read_csv(csv5)

# %%
sorter1 = clean_od.groupby(clean_od['Year']).sum()
sorter_1 = pd.DataFrame(sorter1)
sorter_1
# Out:
#       Total Deaths  Drug Deaths
# Year
# 2015      64861344      1202022
# 2016      65172392      1393204
# 2017      67034290      1651674
# 2018     138911783      3391269

# %%
#scatter plot of all states deaths
tester = clean_od.groupby(clean_od['State']).sum()
grapher = pd.DataFrame(tester)
grapher = grapher.drop(labels = 'Year' , axis = 1)
grapher = grapher.drop(labels = 'US' , axis = 0)
grapher = grapher.sort_values('Drug Deaths' , ascending = False)
plt.scatter(grapher['Total Deaths'] , grapher['Drug Deaths']) 
plt.xlabel('Total Deaths')
plt.ylabel('Drug Deaths')
#grapher.head(10)
#plt.show()
grapher_10 = grapher.head(10)
plt.scatter(grapher_10['Total Deaths'] , grapher_10['Drug Deaths']) 
plt.show()

# %%
grapher
# Out:
#        Total Deaths  Drug Deaths
# State
# PA          8531728       278862
# FL         11292901       255395
# OH          7288470       248120
# CA         13209036       242411
# MI          6224974       155917
# TX         10457741       147934
# NY          6464364       139957
# MA          3714505       127034
# NJ          4145224       119484
# NC          5443276       116092
# IL          4946590       109618
# TN          4721708       107247
# MD          2578061       102207
# GA          5391491        90820
# IN          3825771        90741
# MO          3873517        80870
# YC          3154209        75525
# AZ          2909876        72764
# KY          2360223        69056
# VA          3371953        64229
# WA          3166542        63652
# LA          2669518        60652
# SC          3013003        57240
# WV          1460575        54289
# WI          2599439        51822
# CT          1577549        47573
# NV          1567579        44394
# CO          1705292        43670
# OK          2219317        42871
# AL          2639342        38313
# UT           974751        34332
# MN          2218192        33090
# NM          1064937        29869
# OR          1834913        26706
# NH           623424        22864
# AR          1530383        19562
# MS          1909690        19442
# RI           492889        15175
# KS          1215421        15147
# ME           625506        14473
# IA          1303034        13710
# DC           299651        12574
# HI           691563        11983
# DE           390732        11840
# ID           629991        10537
# AK           239306         7178
# NE           755574         5935
# VT           270790         5544
# MT           457608         5509
# WY           194389         3747
# ND           304550         3164
# SD           350448         2929

# %%
#scatter plot of top 20 overdose deaths
grapher_20 = grapher.head(20)

plt.scatter(grapher_20['Total Deaths'] , grapher_20['Drug Deaths'])
plt.xlabel('Total Deaths')
plt.ylabel('Drug Deaths')

plt.show()

# %%
claimer = op_final_15.groupby(op_final_15['State']).sum()
claimer = claimer.drop(['NPI' , 'Zip Code' , 'PAC ID' ,'Opioid Prescribing Rate' , 'Year'] , axis = 1)
#includes us territories
claimer
#claimer_20 = claimer.head(10)
# Out:
#        Total Claim Count  Opioid Claim Count
# State
# AK               22583.0              1560.0
# AL             1924680.0            145984.0
# AP                 103.0                21.0
# AR              742127.0             52842.0
# AZ              661498.0             50874.0
# CA             3486417.0            226791.0
# CO              579588.0             37298.0
# CT              180382.0              8906.0
# DC               16207.0               749.0
# DE               24076.0              2085.0
# FL             5026933.0            271470.0
# GA             1678738.0            111087.0
# GU               11389.0               280.0
# HI              170597.0              5768.0
# IA              170818.0              7873.0
# ID               60229.0              7704.0
# IL             1425373.0             76488.0
# IN              518564.0             32977.0
# KS              454044.0             29651.0
# KY              783345.0             61180.0
# LA             1664395.0             91480.0
# MA              694769.0             31119.0
# MD              416369.0             19852.0
# ME               30113.0              2505.0
# MI             1854242.0            148823.0
# MN              322988.0             18462.0
# MO             2029779.0            118593.0
# MS              416444.0             22552.0
# MT               26480.0              2442.0
# NC             1240553.0             75170.0
# ND               47710.0              1677.0
# NE              156353.0              9380.0
# NH               50290.0              2616.0
# NJ              636814.0             42106.0
# NM              272505.0             16513.0
# NV              296533.0             23610.0
# NY             2038263.0             64783.0
# OH             1520495.0             90532.0
# OK              586269.0             40484.0
# OR              417782.0             29659.0
# PA             3345082.0            153862.0
# PR               55643.0              1339.0
# RI              124186.0              4262.0
# SC              660593.0             52783.0
# SD               62806.0              3917.0
# TN             1231413.0             74594.0
# TX             3271139.0            201316.0
# UT               54622.0              4174.0
# VA              650459.0             40742.0
# VT                2387.0                81.0
# WA              311167.0             26247.0
# WI              652701.0             35226.0
# WV              355186.0             24832.0
# WY               49849.0              2723.0
# ZZ                 251.0                26.0

# %%
plt.scatter(grapher[''] , claimer['Opioid Claim Count'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(claimer_20['Total Claim Count'] , claimer_20['Opioid Claim Count'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
claimer2 = op_final_16.groupby(op_final_16['State']).sum()
claimer2 = claimer2.drop(['NPI' , 'Zip Code' , 'PAC ID' , 'Opioid Prescribing Rate' ,'Year'] , axis = 1)
#includes us territories
claimer2
#claimer2_20 = claimer2.head(20)
# Out:
#        Total Claim Count  Opioid Claim Count
# State
# AK                8436.0               433.0
# AL              908942.0             64247.0
# AR              562795.0             30750.0
# AZ              820879.0             43630.0
# CA             3337755.0            179709.0
# CO              335877.0             24848.0
# CT              231038.0             10435.0
# DC               25586.0               792.0
# DE               64342.0              2572.0
# FL             5531170.0            300315.0
# GA             2214588.0            138769.0
# GU               14269.0               200.0
# HI              185653.0              6967.0
# IA               80776.0              2621.0
# ID              112843.0             18672.0
# IL             1119936.0             56536.0
# IN              243269.0             14286.0
# KS              138094.0             12077.0
# KY              536387.0             47073.0
# LA              688243.0             32746.0
# MA              959621.0             35041.0
# MD              334115.0             15780.0
# ME               18364.0              1193.0
# MI             1384862.0            106753.0
# MN               53016.0              3088.0
# MO              457957.0             26771.0
# MS              437282.0             25293.0
# MT               12203.0               964.0
# NC             1449555.0             70427.0
# ND                1337.0               284.0
# NE               51062.0              2020.0
# NH               54683.0              2558.0
# NJ              923660.0             37496.0
# NM              135363.0              5424.0
# NV              332670.0             25794.0
# NY             1980926.0             57605.0
# OH             1604784.0             85852.0
# OK              439187.0             47083.0
# OR              283647.0             17495.0
# PA             3381166.0            143258.0
# PR              229574.0              3761.0
# RI               90461.0              4593.0
# SC              736906.0             54782.0
# SD               61478.0              3097.0
# TN             1351719.0             62120.0
# TX             4140949.0            188867.0
# UT              109302.0              7158.0
# VA              437357.0             22946.0
# VI               12143.0               109.0
# VT               25273.0              1763.0
# WA              152486.0              8621.0
# WI              279901.0             12198.0
# WV              268581.0             12405.0
# WY               21738.0               901.0

# %%
plt.scatter(claimer2['Total Claim Count'] , claimer2['Opioid Claim Count'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(claimer2_20['Total Claim Count'] , claimer2_20['Opioid Claim Count'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ind = np.arange(55)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence
p1 = plt.bar(ind, claimer['Opioid Claim Count'], width)
p2 = plt.bar(ind, claimer['Total Claim Count'], width)
plt.show()

# %%
ind = np.arange(20)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence
p1 = plt.bar(ind, claimer_20['Opioid Claim Count'], width)
p2 = plt.bar(ind, claimer_20['Total Claim Count'], width)
plt.show()

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt

# set width of bar
barWidth = 0.25

# set height of bar
bars1 = claimer_20['Opioid Claim Count']
bars2 = claimer_20['Total Claim Count']


# Set position of bar on X axis
r1 = np.arange(0,80000,10)
r2 = np.arange(0,21000,5)

# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='var1')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='var2')

# Add xticks on the middle of the group bars
#plt.xlabel('group', fontweight='bold')

#plt.xticks([r + barWidth for r in range(len(bars1))], ['A', 'B', 'C', 'D', 'E'])

# Create legend & Show graphic
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-cc9aa8e7b6cb> in <module>
#      16
#      17 # Make the plot
# ---> 18 plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='var1')
#      19 plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='var2')
#      20
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2457     return gca().bar(
#    2458         x, height, width=width, bottom=bottom, align=align,
# -> 2459         **({"data": data} if data is not None else {}), **kwargs)
#    2460
#    2461
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2249         x, height, width, y, linewidth = np.broadcast_arrays(
#    2250             # Make args iterable too.
# -> 2251             np.atleast_1d(x), height, width, y, linewidth)
#    2252
#    2253         # Now that units have been converted, set the tick locations.
#
# ~\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     250     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     251
# --> 252     shape = _broadcast_shape(*args)
#     253
#     254     if all(array.shape == shape for array in args):
#
# ~\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     185     # use the old-iterator because np.nditer does not handle size 0 arrays
#     186     # consistently
# --> 187     b = np.broadcast(*args[:32])
#     188     # unfortunately, it cannot handle 32 or more arguments directly
#     189     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
# Setting the positions and width for the bars
pos = list(range(len(claimer_20['Opioid Claim Count']))) 
width = 0.25 
    
# Plotting the bars
fig, ax = plt.subplots(figsize=(10,5))

# Create a bar with pre_score data,
# in position pos,
plt.bar(pos, 
        #using df['pre_score'] data,
        claimer_20['Opioid Claim Count'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224', 
        # with label the first value in first_name
        label=claimer_20['Opioid Claim Count'][0]) 

# Create a bar with mid_score data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        #using df['mid_score'] data,
        claimer_20['Total Claim Count'],
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E', 
        # with label the second value in first_name
        label=claimer_20['Total Claim Count'][1]) 


# Set the y axis label
ax.set_ylabel('Score')

# Set the chart's title
ax.set_title('Test Subject Scores')

# Set the position of the x ticks
ax.set_xticks([p + 1.5 * width for p in pos])

# Set the labels for the x ticks
ax.set_xticklabels(claimer_20[''])

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, max(claimer_20['Opioid Claim Count'] + claimer_20['Total Claim Count'])] )

# Adding the legend and showing the plot
plt.legend(['Pre Score', 'Mid Score', 'Post Score'], loc='upper left')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-b92672b4e0b8> in <module>
#      45
#      46 # Set the labels for the x ticks
# ---> 47 ax.set_xticklabels(claimer_20[''])
#      48
#      49 # Setting the x-axis and y-axis limits
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
