# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import os
import sys
import numpy as np
import scipy as sp

csv1 = '../Presentation/clean/cleaned_overdose.csv'
csv2 = '../Presentation/clean/op_final_15.csv'
csv3 = '../Presentation/clean/op_final_16.csv'
csv4 = '../Presentation/clean/pcgroup_15.csv'
csv5 = '../Presentation/clean/pcgroup_16.csv'
csv6 = '../Presentation/clean/clean_od16.csv'
csv7 = '../Presentation/clean/clean_od15.csv'

clean_od = pd.read_csv(csv1)
op_final_15 = pd.read_csv(csv2)
op_final_16 = pd.read_csv(csv3)
pcgroup_15 = pd.read_csv(csv4)
pcgroup_16 = pd.read_csv(csv5)
clean_od15 = pd.read_csv(csv7)
clean_od16 = pd.read_csv(csv6)

# %%
sorter1 = clean_od.groupby(clean_od['Year']).sum()
sorter_1 = pd.DataFrame(sorter1)
sorter_1
# Out:
#       Total Deaths  Drug Deaths
# Year
# 2015      64861344      1202022
# 2016      65172392      1393204
# 2017      67034290      1651674
# 2018     138911783      3391269

# %%
#scatter plot of all states deaths
tester = clean_od.groupby(clean_od['State']).sum()
grapher = pd.DataFrame(tester)
grapher = grapher.drop(labels = 'Year' , axis = 1)
grapher = grapher.drop(labels = 'US' , axis = 0)
grapher = grapher.sort_values('Drug Deaths' , ascending = False)
plt.scatter(grapher['Total Deaths'] , grapher['Drug Deaths']) 
plt.xlabel('Total Deaths')
plt.ylabel('Drug Deaths')
#grapher.head(10)
#plt.show()
grapher_10 = grapher.head(10)
plt.scatter(grapher_10['Total Deaths'] , grapher_10['Drug Deaths']) 
plt.show()

# %%
grapher
# Out:
#        Total Deaths  Drug Deaths
# State
# PA          8531728       278862
# FL         11292901       255395
# OH          7288470       248120
# CA         13209036       242411
# MI          6224974       155917
# TX         10457741       147934
# NY          6464364       139957
# MA          3714505       127034
# NJ          4145224       119484
# NC          5443276       116092
# IL          4946590       109618
# TN          4721708       107247
# MD          2578061       102207
# GA          5391491        90820
# IN          3825771        90741
# MO          3873517        80870
# YC          3154209        75525
# AZ          2909876        72764
# KY          2360223        69056
# VA          3371953        64229
# WA          3166542        63652
# LA          2669518        60652
# SC          3013003        57240
# WV          1460575        54289
# WI          2599439        51822
# CT          1577549        47573
# NV          1567579        44394
# ...

# %%
#scatter plot of top 20 overdose deaths
grapher_20 = grapher.head(20)

plt.scatter(grapher_20['Total Deaths'] , grapher_20['Drug Deaths'])
plt.xlabel('Total Deaths')
plt.ylabel('Drug Deaths')

plt.show()

# %%
claimer = op_final_15.groupby(op_final_15['State']).sum()
claimer = claimer.drop(['NPI' , 'Zip Code' , 'PAC ID' ,'Opioid Prescribing Rate' , 'Year'] , axis = 1)
#includes us territories
claimer
claimer_20 = claimer.head(20)
claimer_20
# Out:
#        Total Claim Count  Opioid Claim Count
# State
# AK               22583.0              1560.0
# AL             1924680.0            145984.0
# AP                 103.0                21.0
# AR              742127.0             52842.0
# AZ              661498.0             50874.0
# CA             3486417.0            226791.0
# CO              579588.0             37298.0
# CT              180382.0              8906.0
# DC               16207.0               749.0
# DE               24076.0              2085.0
# FL             5026933.0            271470.0
# GA             1678738.0            111087.0
# GU               11389.0               280.0
# HI              170597.0              5768.0
# IA              170818.0              7873.0
# ID               60229.0              7704.0
# IL             1425373.0             76488.0
# IN              518564.0             32977.0
# KS              454044.0             29651.0
# KY              783345.0             61180.0

# %%
#plt.scatter(grapher[''] , claimer['Opioid Claim Count'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(claimer_20['Total Claim Count'] , claimer_20['Opioid Claim Count'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
claimer2 = op_final_16.groupby(op_final_16['State']).sum()
claimer2 = claimer2.drop(['NPI' , 'Zip Code' , 'PAC ID' , 'Opioid Prescribing Rate' ,'Year'] , axis = 1)
#includes us territories
claimer2
claimer2_20 = claimer2.head(20)

# %%
plt.scatter(claimer2['Total Claim Count'] , claimer2['Opioid Claim Count'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(claimer2_20['Total Claim Count'] , claimer2_20['Opioid Claim Count'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ind = np.arange(55)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence
p1 = plt.bar(ind, claimer['Opioid Claim Count'], width)
p2 = plt.bar(ind, claimer['Total Claim Count'], width)
plt.show()

# %%
ind = np.arange(20)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence
p1 = plt.bar(ind, claimer_20['Opioid Claim Count'], width)
p2 = plt.bar(ind, claimer_20['Total Claim Count'], width)
plt.show()

# %%
tester1 = clean_od15.groupby(clean_od['State']).sum()
grapher1 = pd.DataFrame(tester1)
#grapher2 = grapher2.drop(labels = 'Year.1' , axis = 1)
grapher1 = grapher1.drop(labels = 'Year' , axis = 1)
grapher1 = grapher1.drop(labels = 'US' , axis = 0)
grapher1 = grapher1.sort_values('Drug Deaths' , ascending = False)
grapher1_20 = grapher1.head(20)
grapher1_20
# Out:
#        Year.1  Total Deaths  Drug Deaths
# State
# FL     110825      36107408       660573
# DC      98735       3682670        77366
# AL     100750       3545438        57084
# AZ     100750       2204558        48660
# CA      98735       2547585        48021
# AK     110825       2229777        43800
# AR      96720       2516650        41724
# DE      86645       1960491        40452
# GA     126945       1841365        36584
# NM      46345       1633661        27741
# CT     100750       1370936        27487
# CO      88660       1830965        27024
# OK       8060       1030185        18948
# OR      26195        701617        15853
# TN      24180        322951         7339

# %%
tester2 = clean_od16.groupby(clean_od['State']).sum()
grapher2 = pd.DataFrame(tester2)
grapher2 = grapher2.drop(labels = 'Year.1' , axis = 1)
grapher2 = grapher2.drop(labels = 'Year' , axis = 1)
grapher2 = grapher2.drop(labels = 'US' , axis = 0)
grapher2 = grapher2.sort_values('Drug Deaths' , ascending = False)
grapher2
# Out:
#        Total Deaths  Drug Deaths
# State
# FL         36296220       761719
# DC          3667934        91692
# AL          3600755        69539
# AZ          2190946        58980
# CA          2533539        54708
# DE          1947729        49987
# AK          2294016        49169
# AR          2498432        48950
# GA          1848327        41857
# CO          1843372        32281
# CT          1361327        31499
# NM          1664944        28251
# OK          1048933        18875
# OR           714093        15892
# TN           320796         9540

# %%
g = grapher2_20['Drug Deaths']
g = np.asarray(g)

# %%
c15=claimer_20.head(15)

# %%
c15 = claimer_20['Opioid Claim Count']
c15 = np.asarray(c)

# %%
plt.figure(figsize=(40,10))
plt.scatter(g , c15)
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-8cbd79f2e7cc> in <module>
#       1 plt.figure(figsize=(40,10))
# ----> 2 plt.scatter(g , c15)
#       3 plt.show
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...
