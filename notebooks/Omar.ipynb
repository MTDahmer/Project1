# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
csv1 = "../data/Physician_Compare_2015_Individual_EP_Public_Reporting.csv"
csv2 = "../data/Physician_Compare_2016_Individual_EP_Public_Reporting.csv"
csv3 = "../data/Physician_Compare_2015_Group_Patient_Experience.csv"
csv4 = "../data/Physician_Compare_2016_Group_Patient_Experience.csv"

pc_2015 = pd.read_csv(csv1)
pc_2016 = pd.read_csv(csv2)
pc_group_2015 = pd.read_csv(csv3)
pc_group_2016 = pd.read_csv(csv4)

# %%
pc_2015.head()
# Out:
#           NPI    PAC ID Last Name First Name Measure Identifier  \
# 0  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_110_1
# 1  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_111_1
# 2  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_112_1
# 3  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_113_1
# 4  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_128_1
#
#                                        Measure Title Inverse Measure  \
# 0  Preventive Care and Screening: Influenza Immun...               N
# 1      Pneumonia Vaccination Status for Older Adults               N
# 2                            Breast Cancer Screening               N
# 3                        Colorectal Cancer Screening               N
# 4  Preventive Care and Screening: Body Mass Index...               N
#
#    Measure Performance Rate Reporting Mechanism Reported on PC Live Site
# 0                        21                 CLM                        Y
# ...

# %%
pc_2015clean = pc_2015.drop(columns=["PAC ID", "Measure Identifier", "Inverse Measure", "Reporting Mechanism","Reported on PC Live Site"])

pc_2015clean.head()
# Out:
#           NPI Last Name First Name  \
# 0  1508823618   GRIFFIN      DAVID
# 1  1508823618   GRIFFIN      DAVID
# 2  1508823618   GRIFFIN      DAVID
# 3  1508823618   GRIFFIN      DAVID
# 4  1508823618   GRIFFIN      DAVID
#
#                                        Measure Title  Measure Performance Rate
# 0  Preventive Care and Screening: Influenza Immun...                        21
# 1      Pneumonia Vaccination Status for Older Adults                        28
# 2                            Breast Cancer Screening                        37
# 3                        Colorectal Cancer Screening                        22
# 4  Preventive Care and Screening: Body Mass Index...                        42

# %%
pc_2015clean["Year"]= 2015
pc_2015clean.head()
# Out:
#           NPI Last Name First Name  \
# 0  1508823618   GRIFFIN      DAVID
# 1  1508823618   GRIFFIN      DAVID
# 2  1508823618   GRIFFIN      DAVID
# 3  1508823618   GRIFFIN      DAVID
# 4  1508823618   GRIFFIN      DAVID
#
#                                        Measure Title  \
# 0  Preventive Care and Screening: Influenza Immun...
# 1      Pneumonia Vaccination Status for Older Adults
# 2                            Breast Cancer Screening
# 3                        Colorectal Cancer Screening
# 4  Preventive Care and Screening: Body Mass Index...
#
#    Measure Performance Rate  Year
# 0                        21  2015
# 1                        28  2015
# 2                        37  2015
# 3                        22  2015
# 4                        42  2015

# %%
pc_2016.head()
# Out:
#           NPI    PAC ID Last Name First Name Measure Identifier  \
# 0  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_110_1
# 1  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_111_1
# 2  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_113_1
# 3  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_130_1
# 4  1508823618  42100117   GRIFFIN      DAVID      PQRS_EP_226_1
#
#                                        Measure Title Inverse Measure  \
# 0  Preventive Care and Screening: Influenza Immun...               N
# 1      Pneumonia Vaccination Status for Older Adults               N
# 2                        Colorectal Cancer Screening               N
# 3  Documentation of Current Medications in the Me...               N
# 4  Preventive Care and Screening: Tobacco Use: Sc...               N
#
#    Measure Performance Rate  Denominator Count Collection Type  \
# 0                        20                 71             CLM
# ...

# %%
pc_2016clean = pc_2016.drop(columns=["PAC ID", "Measure Identifier", "Inverse Measure", "Denominator Count","Collection Type","Reported on PC Live Site"])

pc_2016clean.head()
# Out:
#           NPI Last Name First Name  \
# 0  1508823618   GRIFFIN      DAVID
# 1  1508823618   GRIFFIN      DAVID
# 2  1508823618   GRIFFIN      DAVID
# 3  1508823618   GRIFFIN      DAVID
# 4  1508823618   GRIFFIN      DAVID
#
#                                        Measure Title  Measure Performance Rate
# 0  Preventive Care and Screening: Influenza Immun...                        20
# 1      Pneumonia Vaccination Status for Older Adults                        41
# 2                        Colorectal Cancer Screening                        29
# 3  Documentation of Current Medications in the Me...                        91
# 4  Preventive Care and Screening: Tobacco Use: Sc...                        98

# %%
pc_2016clean["Year"]= 2016
pc_2016clean.head()

len(pc_2016clean)
# Out:
# 325263

# %%
#merged_pc= pc_2015clean.join(pc_2016clean, on="NPI")
frames = [pc_2015clean, pc_2016clean]

merged_pc = pd.concat(frames)

merged_pc
# Out:
#                NPI    Last Name First Name  \
# 0       1508823618      GRIFFIN      DAVID
# 1       1508823618      GRIFFIN      DAVID
# 2       1508823618      GRIFFIN      DAVID
# 3       1508823618      GRIFFIN      DAVID
# 4       1508823618      GRIFFIN      DAVID
# 5       1508823618      GRIFFIN      DAVID
# 6       1508823618      GRIFFIN      DAVID
# 7       1508823618      GRIFFIN      DAVID
# 8       1508823618      GRIFFIN      DAVID
# 9       1477528776        SPEAR    JEFFREY
# 10      1477528776        SPEAR    JEFFREY
# 11      1154338044    VERBRUGGE       JOHN
# 12      1982641247         JOHN       SAJI
# 13      1285691733     LAPLANTE    DRUANNE
# 14      1285691733     LAPLANTE    DRUANNE
# 15      1285691733     LAPLANTE    DRUANNE
# 16      1285691733     LAPLANTE    DRUANNE
# 17      1285691733     LAPLANTE    DRUANNE
# 18      1285691733     LAPLANTE    DRUANNE
# 19      1033197512   REMANDABAN    TEODULO
# 20      1447242219        PINTO    ANTHONY
# ...

# %%
pc_group_2016.head()
# Out:
#   Organization legal name or 'doing business as' name  Group PAC ID State  \
# 0                  HERITAGE VALLEY MEDICAL GROUP INC       42105678    PA
# 1                  HERITAGE VALLEY MEDICAL GROUP INC       42105678    PA
# 2                  HERITAGE VALLEY MEDICAL GROUP INC       42105678    PA
# 3                  HERITAGE VALLEY MEDICAL GROUP INC       42105678    PA
# 4                  HERITAGE VALLEY MEDICAL GROUP INC       42105678    PA
#
#   Measure Identifier                                      Measure Title  \
# 0        CAHPS_GRP_1  Getting timely care, appointments, and informa...
# 1       CAHPS_GRP_10                       Between visit communication.
# 2       CAHPS_GRP_12                Attention to patient medicine cost.
# 3        CAHPS_GRP_2                   How well clinicians communicate.
# 4        CAHPS_GRP_3                    Patients' rating of clinicians.
#
#    Measure Performance Rate  Denominator Count  Footnote
# ...

# %%
pc_group_2015.head()
# Out:
#   Organization legal name or 'doing business as' name  Group PAC ID  State  \
# 0                  HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 1                  HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 2                  HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 3                  HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 4                  HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
#
#   Measure Identifier                                      Measure Title  \
# 0        CAHPS_GRP_1  Getting timely care, appointments, and informa...
# 1       CAHPS_GRP_10                       Between visit communication.
# 2       CAHPS_GRP_12              Attention to patient medication cost.
# 3        CAHPS_GRP_2                   How well clinicians communicate.
# 4        CAHPS_GRP_3                    Patients' rating of clinicians.
#
#    Measure Performance Rate  Footnote
# 0                      63.0       NaN
# ...
